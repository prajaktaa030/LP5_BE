# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Loading the dataset

# %%
train_df = pd.read_csv('Google_Stock_Price_Train.csv')
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   object
#  1   Open    1258 non-null   float64
#  2   High    1258 non-null   float64
#  3   Low     1258 non-null   float64
#  4   Close   1258 non-null   object
#  5   Volume  1258 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 59.1+ KB

# %%
test_df = pd.read_csv('Google_Stock_Price_Test.csv')
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Open    20 non-null     float64
#  2   High    20 non-null     float64
#  3   Low     20 non-null     float64
#  4   Close   20 non-null     float64
#  5   Volume  20 non-null     object
# dtypes: float64(4), object(2)
# memory usage: 1.1+ KB

# %% [markdown]
# #### Choosing column 'open' for predicition

# %%
train = train_df.loc[:,["Open"]].values
train.shape
# Out:
# (1258, 1)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
# Out:
# C:\Users\Prajakta\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
train_scaled = scaler.fit_transform(train)

# %%
plt.plot(train_scaled)
plt.ylabel("Standardized Values")
plt.xlabel("Time->")
plt.show()

# %% [markdown]
# ### Create data structure to train model
# Taking reference of past 60 days to predict future stock price
# x_train will have data of 60 days prior to current date and y_train will have price on current date

# %%
x_train = []
y_train = []
time = 60
for i in range(60,train_scaled.shape[0]):
    x_train.append(train_scaled[i-60:i,0])
    y_train.append(train_scaled[i,0])
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
x_train.shape,y_train.shape
# Out:
# ((1198, 60), (1198,))

# %%
x_train = np.reshape(x_train,newshape=(x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (1198, 60, 1)

# %% [markdown]
# ### Build model

# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN,Dropout

# %%
model = Sequential()

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True, input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50))
model.add(Dropout(0.2))

model.add(Dense(units=1))

model.compile(optimizer='adam',loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 60, 50)            2600
#
#  dropout (Dropout)           (None, 60, 50)            0
#
#  simple_rnn_1 (SimpleRNN)    (None, 60, 50)            5050
#
#  dropout_1 (Dropout)         (None, 60, 50)            0
#
#  simple_rnn_2 (SimpleRNN)    (None, 60, 50)            5050
#
#  dropout_2 (Dropout)         (None, 60, 50)            0
#
#  simple_rnn_3 (SimpleRNN)    (None, 50)                5050
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 17801 (69.54 KB)
# Trainable params: 17801 (69.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x_train,y_train,epochs=100,batch_size=30,validation_split=0.05)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 6s 63ms/step - loss: 0.3566 - val_loss: 0.0419
# Epoch 2/100
# 38/38 [==============================] - 2s 42ms/step - loss: 0.2603 - val_loss: 0.0014
# Epoch 3/100
# 38/38 [==============================] - 2s 42ms/step - loss: 0.1631 - val_loss: 0.0050
# Epoch 4/100
# 38/38 [==============================] - 2s 42ms/step - loss: 0.1434 - val_loss: 8.0325e-04
# Epoch 5/100
# 38/38 [==============================] - 2s 49ms/step - loss: 0.1094 - val_loss: 0.0049
# Epoch 6/100
# 38/38 [==============================] - 2s 52ms/step - loss: 0.1024 - val_loss: 0.0056
# Epoch 7/100
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0775 - val_loss: 9.9754e-04
# Epoch 8/100
# 38/38 [==============================] - 2s 53ms/step - loss: 0.0640 - val_loss: 7.5682e-04
# Epoch 9/100
# 38/38 [==============================] - 2s 56ms/step - loss: 0.0618 - val_loss: 0.0117
# Epoch 10/100
# 38/38 [==============================] - 2s 48ms/step - loss: 0.0506 - val_loss: 0.0038
# Epoch 11/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0449 - val_loss: 0.0177
# Epoch 12/100
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0392 - val_loss: 0.0022
# Epoch 13/100
# 38/38 [==============================] - 2s 54ms/step - loss: 0.0335 - val_loss: 0.0079
# Epoch 14/100
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0324 - val_loss: 0.0021
# Epoch 15/100
# 38/38 [==============================] - 2s 48ms/step - loss: 0.0295 - val_loss: 0.0146
# Epoch 16/100
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0246 - val_loss: 0.0038
# Epoch 17/100
# 38/38 [==============================] - 2s 46ms/step - loss: 0.0223 - val_loss: 0.0013
# Epoch 18/100
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0188 - val_loss: 0.0021
# Epoch 19/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0178 - val_loss: 0.0034
# Epoch 20/100
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0181 - val_loss: 0.0038
# Epoch 21/100
# 38/38 [==============================] - 2s 48ms/step - loss: 0.0168 - val_loss: 0.0131
# Epoch 22/100
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0156 - val_loss: 0.0042
# Epoch 23/100
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0147 - val_loss: 9.8525e-04
# Epoch 24/100
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0145 - val_loss: 0.0025
# Epoch 25/100
# 38/38 [==============================] - 2s 49ms/step - loss: 0.0119 - val_loss: 0.0033
# Epoch 26/100
# 38/38 [==============================] - 2s 54ms/step - loss: 0.0121 - val_loss: 0.0028
# Epoch 27/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0118 - val_loss: 0.0076
# Epoch 28/100
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0101 - val_loss: 7.6985e-04
# Epoch 29/100
# 38/38 [==============================] - 2s 56ms/step - loss: 0.0110 - val_loss: 9.4244e-04
# Epoch 30/100
# 38/38 [==============================] - 2s 48ms/step - loss: 0.0087 - val_loss: 0.0057
# Epoch 31/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0086 - val_loss: 0.0019
# Epoch 32/100
# 38/38 [==============================] - 2s 59ms/step - loss: 0.0078 - val_loss: 0.0048
# Epoch 33/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0075 - val_loss: 0.0055
# Epoch 34/100
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0072 - val_loss: 0.0032
# Epoch 35/100
# 38/38 [==============================] - 2s 43ms/step - loss: 0.0067 - val_loss: 0.0038
# Epoch 36/100
# 38/38 [==============================] - 2s 41ms/step - loss: 0.0062 - val_loss: 0.0032
# Epoch 37/100
# 38/38 [==============================] - 2s 48ms/step - loss: 0.0070 - val_loss: 0.0016
# Epoch 38/100
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0061 - val_loss: 0.0021
# Epoch 39/100
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0055 - val_loss: 0.0014
# Epoch 40/100
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 41/100
# 38/38 [==============================] - 2s 41ms/step - loss: 0.0058 - val_loss: 5.4814e-04
# Epoch 42/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0051 - val_loss: 7.7892e-04
# Epoch 43/100
# 38/38 [==============================] - 2s 46ms/step - loss: 0.0056 - val_loss: 0.0026
# Epoch 44/100
# 38/38 [==============================] - 2s 49ms/step - loss: 0.0048 - val_loss: 0.0013
# Epoch 45/100
# 38/38 [==============================] - 2s 53ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 46/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0048 - val_loss: 5.3258e-04
# Epoch 47/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0046 - val_loss: 5.9853e-04
# Epoch 48/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0044 - val_loss: 0.0022
# Epoch 49/100
# 38/38 [==============================] - 3s 68ms/step - loss: 0.0044 - val_loss: 0.0010
# Epoch 50/100
# 38/38 [==============================] - 3s 72ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 51/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0039 - val_loss: 9.4231e-04
# Epoch 52/100
# 38/38 [==============================] - 3s 71ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 53/100
# 38/38 [==============================] - 3s 75ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 54/100
# 38/38 [==============================] - 3s 69ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 55/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0036 - val_loss: 6.0660e-04
# Epoch 56/100
# 38/38 [==============================] - 2s 65ms/step - loss: 0.0035 - val_loss: 6.6702e-04
# Epoch 57/100
# 38/38 [==============================] - 3s 71ms/step - loss: 0.0038 - val_loss: 8.6853e-04
# Epoch 58/100
# 38/38 [==============================] - 3s 76ms/step - loss: 0.0030 - val_loss: 7.3614e-04
# Epoch 59/100
# 38/38 [==============================] - 3s 74ms/step - loss: 0.0030 - val_loss: 5.3187e-04
# Epoch 60/100
# 38/38 [==============================] - 3s 72ms/step - loss: 0.0033 - val_loss: 7.9184e-04
# Epoch 61/100
# 38/38 [==============================] - 3s 72ms/step - loss: 0.0034 - val_loss: 8.6994e-04
# Epoch 62/100
# 38/38 [==============================] - 2s 54ms/step - loss: 0.0031 - val_loss: 0.0010
# Epoch 63/100
# 38/38 [==============================] - 3s 75ms/step - loss: 0.0031 - val_loss: 5.5485e-04
# Epoch 64/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0029 - val_loss: 6.8737e-04
# Epoch 65/100
# 38/38 [==============================] - 2s 56ms/step - loss: 0.0030 - val_loss: 5.3266e-04
# Epoch 66/100
# 38/38 [==============================] - 3s 66ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 67/100
# 38/38 [==============================] - 3s 69ms/step - loss: 0.0031 - val_loss: 5.4590e-04
# Epoch 68/100
# 38/38 [==============================] - 3s 72ms/step - loss: 0.0030 - val_loss: 5.7823e-04
# Epoch 69/100
# 38/38 [==============================] - 3s 70ms/step - loss: 0.0029 - val_loss: 6.2809e-04
# Epoch 70/100
# 38/38 [==============================] - 3s 72ms/step - loss: 0.0029 - val_loss: 7.5980e-04
# Epoch 71/100
# 38/38 [==============================] - 3s 69ms/step - loss: 0.0026 - val_loss: 6.8180e-04
# Epoch 72/100
# 38/38 [==============================] - 2s 59ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 73/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 74/100
# 38/38 [==============================] - 3s 67ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 75/100
# 38/38 [==============================] - 3s 67ms/step - loss: 0.0025 - val_loss: 9.2807e-04
# Epoch 76/100
# 38/38 [==============================] - 3s 72ms/step - loss: 0.0025 - val_loss: 7.2218e-04
# Epoch 77/100
# 38/38 [==============================] - 3s 72ms/step - loss: 0.0027 - val_loss: 6.3083e-04
# Epoch 78/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0027 - val_loss: 7.2146e-04
# Epoch 79/100
# 38/38 [==============================] - 3s 69ms/step - loss: 0.0024 - val_loss: 5.5272e-04
# Epoch 80/100
# 38/38 [==============================] - 2s 65ms/step - loss: 0.0024 - val_loss: 5.4456e-04
# Epoch 81/100
# 38/38 [==============================] - 3s 71ms/step - loss: 0.0024 - val_loss: 5.3777e-04
# Epoch 82/100
# 38/38 [==============================] - 3s 67ms/step - loss: 0.0026 - val_loss: 5.3256e-04
# Epoch 83/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0025 - val_loss: 5.2633e-04
# Epoch 84/100
# 38/38 [==============================] - 3s 72ms/step - loss: 0.0023 - val_loss: 7.6480e-04
# Epoch 85/100
# 38/38 [==============================] - 3s 70ms/step - loss: 0.0021 - val_loss: 9.6833e-04
# Epoch 86/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0025 - val_loss: 6.4694e-04
# Epoch 87/100
# 38/38 [==============================] - 3s 67ms/step - loss: 0.0023 - val_loss: 5.3924e-04
# Epoch 88/100
# 38/38 [==============================] - 3s 67ms/step - loss: 0.0023 - val_loss: 9.7441e-04
# Epoch 89/100
# 38/38 [==============================] - 3s 70ms/step - loss: 0.0024 - val_loss: 7.0466e-04
# Epoch 90/100
# 38/38 [==============================] - 2s 65ms/step - loss: 0.0020 - val_loss: 7.7662e-04
# Epoch 91/100
# 38/38 [==============================] - 3s 67ms/step - loss: 0.0022 - val_loss: 8.3111e-04
# Epoch 92/100
# 38/38 [==============================] - 3s 66ms/step - loss: 0.0022 - val_loss: 9.0424e-04
# Epoch 93/100
# 38/38 [==============================] - 2s 50ms/step - loss: 0.0021 - val_loss: 5.3723e-04
# Epoch 94/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0021 - val_loss: 8.6696e-04
# Epoch 95/100
# 38/38 [==============================] - 3s 74ms/step - loss: 0.0023 - val_loss: 6.7931e-04
# Epoch 96/100
# 38/38 [==============================] - 2s 56ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 97/100
# 38/38 [==============================] - 3s 69ms/step - loss: 0.0020 - val_loss: 6.6544e-04
# Epoch 98/100
# 38/38 [==============================] - 3s 70ms/step - loss: 0.0021 - val_loss: 9.6489e-04
# Epoch 99/100
# 38/38 [==============================] - 3s 69ms/step - loss: 0.0021 - val_loss: 5.1762e-04
# Epoch 100/100
# 38/38 [==============================] - 3s 68ms/step - loss: 0.0019 - val_loss: 5.2809e-04

# %% [markdown]
# ### Prepare test dataset

# %%
data = pd.concat((train_df['Open'],test_df['Open']),axis=0)

# %%
test_input = data.iloc[len(data) - len(test_df) - time : ].values
test_input.shape
# Out:
# (80,)

# %%
test_input = test_input.reshape(-1,1)
test_input.shape
# Out:
# (80, 1)

# %%
test_scaled = scaler.transform(test_input)

# %% [markdown]
# #### Create test data set

# %%
x_test = []
for i in range(time,test_scaled.shape[0]):
    x_test.append(test_scaled[i - time: i,0 ])
x_test = np.array(x_test)
x_test.shape
# Out:
# (20, 60)

# %%
x_test = np.reshape(x_test,newshape=(x_test.shape[0],x_test.shape[1],1))
x_test.shape
# Out:
# (20, 60, 1)

# %%
y_test = test_df.loc[:,"Open"].values

# %% [markdown]
# ### Model Prediction

# %%
y_pred = model.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 485ms/step

# %%
y_pred = scaler.inverse_transform(y_pred)

# %%
output = model.evaluate(x=x_test,y=y_test)
# Out:
# 1/1 [==============================] - 0s 392ms/step - loss: 650779.1875

# %%
plt.plot(y_test, color = 'red', label = 'Real price')
plt.plot(y_pred, color = 'blue', label = 'Predicted price')

plt.title('Google Stock price prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
